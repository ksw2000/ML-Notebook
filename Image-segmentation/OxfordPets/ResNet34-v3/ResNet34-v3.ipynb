# %% [markdown]
# # Image Segmentation U-Net
#
# + [https://ithelp.ithome.com.tw/articles/10240314](https://ithelp.ithome.com.tw/articles/10240314)
# + [https://www.kaggle.com/tikutiku/hubmap-tilespadded-inference-v2](https://www.kaggle.com/tikutiku/hubmap-tilespadded-inference-v2)
#
# Decoder 上採樣過程改以反卷積來實作

# %% [markdown]
# # Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !tar -xf "/content/drive/MyDrive/Colab Notebooks/annotations.tar.gz" -C /content
# !tar -xf "/content/drive/MyDrive/Colab Notebooks/images.tar.gz" -C /content

# %%
import os

# https://stackoverflow.com/questions/60058588/tesnorflow-2-0-tf-random-set-seed-not-working-since-i-am-getting-different-resul
SEED = 2021
os.environ['PYTHONHASHSEED'] = str(SEED)

# %%
import numpy
import math
import random

VERSION = 'ResNet34-UNet-v3'
DATA_ROOT_DIR = '/content/'
SEED = 2021
IMG_SIZE = (160, 160)
NUM_CLASSES = 4
BATCH_SIZE = 20
EPOCHES = 50

import tensorflow.keras as keras
from keras import layers, models
import tensorflow as tf

def reset_random_seed():
    os.environ['PYTHONHASHSEED'] = str(SEED)
    numpy.random.seed(SEED)
    random.seed(SEED)
    tf.random.set_seed(SEED)
reset_random_seed()

# %%
files = []

for file in os.listdir(DATA_ROOT_DIR + 'images'):
    # file = Abyssinian_1.jpg
    if file.endswith('jpg'):
        fn = file.split('.')[0]
        if os.path.isfile(DATA_ROOT_DIR + 'annotations/trimaps/' + fn + '.png'):
            files.append(fn)
files = sorted(files)

# %%
from IPython.display import display
from tensorflow.keras.preprocessing.image import load_img
from PIL import ImageOps
import PIL

# ImageOps.autocontrast() method maximizes (normalize) image contrast. 
# This function calculates a histogram of the input image, 
# removes cutoff percent of the lightest and darkest pixels from the histogram, 
# and remaps the image so that the darkest pixel becomes black (0), 
# and the lightest becomes white (255).

img = PIL.ImageOps.autocontrast(load_img(DATA_ROOT_DIR + 'annotations/trimaps/' + files[0] + '.png'))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7FA3D59F0F10>

# %% [markdown]
# ## Data Generator

# %%
# reference: https://www.tensorflow.org/api_docs/python/tf/keras/utils/Sequence
class OxfordPets(keras.utils.Sequence):
    def __init__(self, files):
        self.files = files
    def __len__(self):
        return math.ceil(len(self.files) / BATCH_SIZE)
    def __getitem__(self, index):
        x, y = [], []
        for i in range(index * BATCH_SIZE, min((index+1) * BATCH_SIZE, len(self.files))):
            # target size in load_img
            # (img_height, img_width)
            x.append(numpy.array(load_img(DATA_ROOT_DIR + 'images/' + self.files[i] + '.jpg', target_size = IMG_SIZE), dtype='float32'))
            y.append(numpy.array(load_img(DATA_ROOT_DIR + 'annotations/trimaps/' + self.files[i] + '.png', target_size = IMG_SIZE, color_mode="grayscale"), dtype='uint8'))

        return numpy.array(x), numpy.array(y)

# %% [markdown]
# ## Build model

# %%
class ResBlock(keras.Model):
    def __init__(self, channels, strides=1):
        super().__init__()

        self.conv1 = layers.Conv2D(
            channels, 3, strides=strides, padding='same', use_bias=False)
        self.bn1 = layers.BatchNormalization()
        self.conv2 = layers.Conv2D(
            channels, 3, strides=1, padding='same', use_bias=False)
        self.bn2 = layers.BatchNormalization()

        if strides != 1:
            self.shortcut = keras.Sequential([
                layers.Conv2D(channels, 1, strides,
                              padding='same', use_bias=False)
            ])
        else:
            self.shortcut = keras.Sequential()

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.bn1(x)
        x = tf.nn.relu(x)

        x = self.conv2(x)
        x = self.bn2(x)

        shortcut = self.shortcut(inputs)
        return tf.nn.relu(tf.add(x, shortcut))

    def get_config(self):
        return {}


class Encoder(keras.Model):
    def __init__(self, channels, repeat, strides):
        super().__init__()
        self.resBlocks = keras.Sequential()
        self.resBlocks.add(ResBlock(channels, strides))
        self.cbam = CBAM(reduction=16)
        for _ in range(1, repeat):
            self.resBlocks.add(ResBlock(channels, strides=1))
        
    def call(self, inputs):
        x = self.cbam(inputs)
        return self.resBlocks(x)

    def get_config(self):
        return {}


class ChannelAttention(keras.Model):
    def __init__(self, reduction):
        super().__init__()
        self.globalMaxPool = layers.GlobalMaxPooling2D(keepdims=True)
        self.globalAvgPool = layers.GlobalAveragePooling2D(keepdims=True)
        self.reduction = reduction

    def build(self, input_shape):
        self.fc = keras.Sequential([
            layers.Conv2D(input_shape[-1]//self.reduction, 3, padding='same'),
            layers.ReLU(),
            layers.Conv2D(input_shape[-1], 1, padding='valid')
        ])

    def call(self, inputs):
        x1 = self.globalMaxPool(inputs)
        x2 = self.globalAvgPool(inputs)
        x1 = self.fc(x1)
        x2 = self.fc(x2)
        x = tf.nn.sigmoid(layers.add([x1, x2]))
        return x


class SpatialAttention(keras.Model):
    def __init__(self):
        super().__init__()
        self.conv3x3 = layers.Conv2D(1, 3, padding='same')

    def call(self, inputs):
        # https://github.com/kobiso/CBAM-tensorflow/blob/master/attention_module.py#L95
        x1 = tf.math.reduce_max(inputs, axis=3, keepdims=True)
        x2 = tf.math.reduce_mean(inputs, axis=3, keepdims=True)
        x = tf.concat([x1, x2], 3)
        x = self.conv3x3(x)
        x = tf.nn.sigmoid(x)
        return x


class CBAM(keras.Model):
    def __init__(self, reduction):
        super().__init__()
        self.channelAttention = ChannelAttention(reduction)
        self.spaialAttention = SpatialAttention()

    def call(self, inputs):
        x = inputs * self.channelAttention(inputs)
        x = x * self.spaialAttention(x)
        return x

class Decoder(keras.Model):
    def __init__(self, channels, use_upsample=True):
        super().__init__()
        self.bn1 = layers.BatchNormalization()
        self.bn2 = layers.BatchNormalization()
        self.bn3 = layers.BatchNormalization()
        
        if use_upsample:
            self.upsample = layers.Conv2DTranspose(channels, 3, strides=2, padding='same', use_bias=False)
        else:
            self.upsample = keras.Sequential()

        self.conv3x3 = layers.Conv2D(channels, 3, strides=1, padding='same', use_bias=False)
        self.conv1x1 = layers.Conv2D(channels, 1, use_bias=False)

    def call(self, inputs):
        x = self.bn1(inputs)
        x = tf.nn.relu(x)
        
        # 反卷積
        x = self.upsample(x)
        x = self.bn2(x)
        x = tf.nn.relu(x)
        
        x = self.conv3x3(x)
        x = self.bn3(x)

        shortcut = self.conv1x1(self.upsample(inputs))
        x += shortcut
        return x

    def get_config(self):
        return {}


def ResNet34UNetV3(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Encode by ResNet34
    x = layers.Conv2D(64, 7, strides=2, padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = tf.nn.relu(x)
    x0 = layers.MaxPooling2D(3, strides=2, padding='same')(x)

    # ResNet34
    x1 = Encoder(64, 3, strides=1)(x0)
    x2 = Encoder(128, 4, strides=2)(x1)
    x3 = Encoder(256, 6, strides=2)(x2)
    x4 = Encoder(512, 3, strides=2)(x3)

    # Center Block
    y5 = layers.Conv2D(512, 3, padding='same', use_bias=False)(x4)

    # Decode
    y4 = Decoder(64)(layers.Concatenate(axis=3)([x4, y5]))
    y3 = Decoder(64)(layers.Concatenate(axis=3)([x3, y4]))
    y2 = Decoder(64)(layers.Concatenate(axis=3)([x2, y3]))
    y1 = Decoder(64)(layers.Concatenate(axis=3)([x1, y2]))
    y0 = Decoder(64)(y1)

    # Hypercolumn
    y4 = layers.UpSampling2D(16, interpolation='bilinear')(y4)
    y3 = layers.UpSampling2D(8, interpolation='bilinear')(y3)
    y2 = layers.UpSampling2D(4, interpolation='bilinear')(y2)
    y1 = layers.UpSampling2D(2, interpolation='bilinear')(y1)
    hypercolumn = layers.Concatenate(axis=3)([y0, y1, y2, y3, y4])

    # Final conv
    outputs = keras.Sequential([
        layers.Conv2D(64, 3, padding='same', use_bias=False),
        layers.ELU(),
        layers.Conv2D(num_classes, 1, use_bias=False)
    ])(hypercolumn)

    outputs = tf.nn.softmax(outputs)
    return keras.Model(inputs, outputs)

# %% [markdown]
# ## Start Training!

# %%
keras.backend.clear_session()
reset_random_seed()

m = ResNet34UNetV3(IMG_SIZE+(3,), NUM_CLASSES)
m.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 80, 80, 64)   9408        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 80, 80, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu (TFOpLambda)         (None, 80, 80, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 40, 40, 64)   0           tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# encoder (Encoder)               (None, 40, 40, 64)   225367      max_pooling2d[0][0]
# __________________________________________________________________________________________________
# encoder_1 (Encoder)             (None, 20, 20, 128)  1120855     encoder[0][0]
# __________________________________________________________________________________________________
# encoder_2 (Encoder)             (None, 10, 10, 256)  6838427     encoder_1[0][0]
# __________________________________________________________________________________________________
# encoder_3 (Encoder)             (None, 5, 5, 512)    13160739    encoder_2[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 5, 5, 512)    2359296     encoder_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 5, 5, 1024)   0           encoder_3[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# decoder (Decoder)               (None, 10, 10, 64)   635392      concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 10, 10, 320)  0           encoder_2[0][0]
#                                                                  decoder[0][0]
# __________________________________________________________________________________________________
# decoder_1 (Decoder)             (None, 20, 20, 64)   227072      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 20, 20, 192)  0           encoder_1[0][0]
#                                                                  decoder_1[0][0]
# __________________________________________________________________________________________________
# decoder_2 (Decoder)             (None, 40, 40, 64)   152832      concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 40, 40, 128)  0           encoder[0][0]
#                                                                  decoder_2[0][0]
# __________________________________________________________________________________________________
# decoder_3 (Decoder)             (None, 80, 80, 64)   115712      concatenate_3[0][0]
# __________________________________________________________________________________________________
# decoder_4 (Decoder)             (None, 160, 160, 64) 78592       decoder_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 160, 160, 64) 0           decoder_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 160, 160, 64) 0           decoder_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 160, 160, 64) 0           decoder_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 160, 160, 64) 0           decoder[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 160, 160, 320 0           decoder_4[0][0]
#                                                                  up_sampling2d_3[0][0]
#                                                                  up_sampling2d_2[0][0]
#                                                                  up_sampling2d_1[0][0]
#                                                                  up_sampling2d[0][0]
# __________________________________________________________________________________________________
# sequential_20 (Sequential)      (None, 160, 160, 4)  184576      concatenate_4[0][0]
# __________________________________________________________________________________________________
# tf.nn.softmax (TFOpLambda)      (None, 160, 160, 4)  0           sequential_20[0][0]
# ==================================================================================================
# Total params: 25,108,524
# Trainable params: 25,088,556
# Non-trainable params: 19,968
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(m, show_shapes=True)

# %%
files = sorted(files)
rng = numpy.random.default_rng(SEED)
rng.shuffle(files)

middle = math.ceil(len(files) * 0.8)
train = OxfordPets(files[:middle])
test = OxfordPets(files[middle:])

# 確定每次訓練時 files 的順序皆相同
print(files[:10])
# Out:
# ['japanese_chin_19', 'english_setter_184', 'Bengal_103', 'Bengal_12', 'american_bulldog_133', 'shiba_inu_12', 'Bombay_69', 'leonberger_189', 'Bombay_171', 'saint_bernard_103']

# %%
keras.backend.clear_session()
reset_random_seed()

callbacks = [
    keras.callbacks.ModelCheckpoint(DATA_ROOT_DIR + VERSION + ".h5", monitor='val_loss', save_best_only=True, save_weights_only=True)
]

m.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=['accuracy'])
history = m.fit(train, validation_data=test, epochs=EPOCHES, callbacks=callbacks)
# Out:
# Epoch 1/50
# 296/296 [==============================] - 145s 403ms/step - loss: 0.7920 - accuracy: 0.7132 - val_loss: 0.7043 - val_accuracy: 0.7002
# Epoch 2/50
# 296/296 [==============================] - 117s 396ms/step - loss: 0.5509 - accuracy: 0.7792 - val_loss: 0.5672 - val_accuracy: 0.7764
# Epoch 3/50
# 296/296 [==============================] - 119s 403ms/step - loss: 0.4683 - accuracy: 0.8166 - val_loss: 1.3955 - val_accuracy: 0.6759
# Epoch 4/50
# 296/296 [==============================] - 120s 405ms/step - loss: 0.4197 - accuracy: 0.8368 - val_loss: 0.4642 - val_accuracy: 0.8213
# Epoch 5/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.3825 - accuracy: 0.8513 - val_loss: 0.4919 - val_accuracy: 0.8113
# Epoch 6/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.3619 - accuracy: 0.8601 - val_loss: 0.4698 - val_accuracy: 0.8287
# Epoch 7/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.3385 - accuracy: 0.8685 - val_loss: 0.5974 - val_accuracy: 0.7619
# Epoch 8/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.3244 - accuracy: 0.8749 - val_loss: 0.3871 - val_accuracy: 0.8548
# Epoch 9/50
# 296/296 [==============================] - 120s 407ms/step - loss: 0.3088 - accuracy: 0.8805 - val_loss: 0.5495 - val_accuracy: 0.8551
# Epoch 10/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.2932 - accuracy: 0.8867 - val_loss: 0.4794 - val_accuracy: 0.8267
# Epoch 11/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.2853 - accuracy: 0.8889 - val_loss: 0.6191 - val_accuracy: 0.8015
# Epoch 12/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.2792 - accuracy: 0.8916 - val_loss: 0.4856 - val_accuracy: 0.8373
# Epoch 13/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.2620 - accuracy: 0.8978 - val_loss: 0.4420 - val_accuracy: 0.8363
# Epoch 14/50
# 296/296 [==============================] - 121s 408ms/step - loss: 0.2608 - accuracy: 0.8979 - val_loss: 0.4108 - val_accuracy: 0.8602
# Epoch 15/50
# 296/296 [==============================] - 120s 407ms/step - loss: 0.2395 - accuracy: 0.9063 - val_loss: 0.6618 - val_accuracy: 0.8167
# Epoch 16/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.2341 - accuracy: 0.9079 - val_loss: 0.3934 - val_accuracy: 0.8501
# Epoch 17/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.2292 - accuracy: 0.9104 - val_loss: 0.3385 - val_accuracy: 0.8769
# Epoch 18/50
# 296/296 [==============================] - 121s 408ms/step - loss: 0.2243 - accuracy: 0.9117 - val_loss: 0.3712 - val_accuracy: 0.8678
# Epoch 19/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.2164 - accuracy: 0.9145 - val_loss: 0.3318 - val_accuracy: 0.8816
# Epoch 20/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.2035 - accuracy: 0.9191 - val_loss: 0.3780 - val_accuracy: 0.8668
# Epoch 21/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.2009 - accuracy: 0.9200 - val_loss: 0.3943 - val_accuracy: 0.8683
# Epoch 22/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.2077 - accuracy: 0.9175 - val_loss: 0.3020 - val_accuracy: 0.8912
# Epoch 23/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.1874 - accuracy: 0.9249 - val_loss: 0.3187 - val_accuracy: 0.8878
# Epoch 24/50
# 296/296 [==============================] - 121s 408ms/step - loss: 0.1804 - accuracy: 0.9276 - val_loss: 0.3191 - val_accuracy: 0.8897
# Epoch 25/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.1786 - accuracy: 0.9279 - val_loss: 0.3170 - val_accuracy: 0.8938
# Epoch 26/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.1666 - accuracy: 0.9320 - val_loss: 0.3805 - val_accuracy: 0.8777
# Epoch 27/50
# 296/296 [==============================] - 121s 408ms/step - loss: 0.1569 - accuracy: 0.9355 - val_loss: 0.3732 - val_accuracy: 0.8800
# Epoch 28/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.1808 - accuracy: 0.9269 - val_loss: 0.3339 - val_accuracy: 0.8846
# Epoch 29/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.1558 - accuracy: 0.9359 - val_loss: 0.3013 - val_accuracy: 0.8994
# Epoch 30/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.1388 - accuracy: 0.9419 - val_loss: 0.3315 - val_accuracy: 0.9021
# Epoch 31/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.1502 - accuracy: 0.9382 - val_loss: 0.4275 - val_accuracy: 0.8692
# Epoch 32/50
# 296/296 [==============================] - 120s 407ms/step - loss: 0.1571 - accuracy: 0.9353 - val_loss: 0.3462 - val_accuracy: 0.8932
# Epoch 33/50
# 296/296 [==============================] - 120s 407ms/step - loss: 0.1431 - accuracy: 0.9406 - val_loss: 0.4211 - val_accuracy: 0.8727
# Epoch 34/50
# 296/296 [==============================] - 120s 407ms/step - loss: 0.1449 - accuracy: 0.9398 - val_loss: 0.3313 - val_accuracy: 0.9033
# Epoch 35/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.1204 - accuracy: 0.9489 - val_loss: 0.3467 - val_accuracy: 0.9041
# Epoch 36/50
# 296/296 [==============================] - 120s 407ms/step - loss: 0.1103 - accuracy: 0.9528 - val_loss: 0.3607 - val_accuracy: 0.9041
# Epoch 37/50
# 296/296 [==============================] - 120s 407ms/step - loss: 0.1037 - accuracy: 0.9555 - val_loss: 0.3678 - val_accuracy: 0.9030
# Epoch 38/50
# 296/296 [==============================] - 120s 407ms/step - loss: 0.0985 - accuracy: 0.9577 - val_loss: 0.3932 - val_accuracy: 0.9026
# Epoch 39/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.0968 - accuracy: 0.9584 - val_loss: 0.4180 - val_accuracy: 0.9041
# Epoch 40/50
# 296/296 [==============================] - 120s 406ms/step - loss: 0.1653 - accuracy: 0.9337 - val_loss: 0.3608 - val_accuracy: 0.8741
# Epoch 41/50
# 296/296 [==============================] - 120s 407ms/step - loss: 0.1471 - accuracy: 0.9394 - val_loss: 0.3615 - val_accuracy: 0.8966
# Epoch 42/50
# 296/296 [==============================] - 120s 406ms/step - loss: 0.1033 - accuracy: 0.9558 - val_loss: 0.3836 - val_accuracy: 0.9033
# Epoch 43/50
# 296/296 [==============================] - 120s 406ms/step - loss: 0.0895 - accuracy: 0.9614 - val_loss: 0.4189 - val_accuracy: 0.9045
# Epoch 44/50
# 296/296 [==============================] - 120s 406ms/step - loss: 0.0816 - accuracy: 0.9647 - val_loss: 0.4478 - val_accuracy: 0.9049
# Epoch 45/50
# 296/296 [==============================] - 120s 406ms/step - loss: 0.0773 - accuracy: 0.9666 - val_loss: 0.4504 - val_accuracy: 0.9038
# Epoch 46/50
# 296/296 [==============================] - 121s 407ms/step - loss: 0.0744 - accuracy: 0.9679 - val_loss: 0.4929 - val_accuracy: 0.9038
# Epoch 47/50
# 296/296 [==============================] - 120s 407ms/step - loss: 0.0727 - accuracy: 0.9687 - val_loss: 0.4849 - val_accuracy: 0.9006
# Epoch 48/50
# 296/296 [==============================] - 120s 406ms/step - loss: 0.0707 - accuracy: 0.9695 - val_loss: 0.5046 - val_accuracy: 0.9038
# Epoch 49/50
# 296/296 [==============================] - 120s 406ms/step - loss: 0.0687 - accuracy: 0.9704 - val_loss: 0.4884 - val_accuracy: 0.9037
# Epoch 50/50
# 296/296 [==============================] - 120s 406ms/step - loss: 0.0682 - accuracy: 0.9706 - val_loss: 0.5304 - val_accuracy: 0.9009

# %% [markdown]
# # Evaluate

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 2])
plt.legend(loc='upper right')

print(min(history.history['val_loss']))
# Out:
# 0.3012981414794922

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

print(max(history.history['val_accuracy']))
# Out:
# 0.9049441814422607

# %%
import json
with open(DATA_ROOT_DIR + VERSION + '.json', 'w') as f:
    data = {
        'loss': history.history['loss'],
        'val_loss': history.history['val_loss']
    }
    json.dump(data, f)

# %% [markdown]
# ## Show result

# %%
def mask_to_img(predict):
    mask = numpy.argmax(predict, axis=-1)
    # numpy.expand_dims() expand the shape of an array.
    # Insert a new axis that will appear at the axis position in the expanded
    # array shape.
    mask = numpy.expand_dims(mask, axis = -1)
    return PIL.ImageOps.autocontrast(keras.preprocessing.image.array_to_img(mask))

# %%
demo_data = OxfordPets(files[:20])
demo_res = m.predict(demo_data)

plt.figure(figsize=(8, 10))
for i in range(20):
    plt.subplot(5, 4, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(keras.preprocessing.image.array_to_img(demo_data.__getitem__(0)[0][i]))
    plt.imshow(mask_to_img(demo_res[i]), cmap='jet', alpha=0.3)

plt.show()
plt.close()

# %%
import shutil
val_loss = min(history.history['val_loss'])

shutil.copy(DATA_ROOT_DIR + VERSION + '.json', '/content/drive/MyDrive/Models/%s-%.4f.json' % (VERSION, val_loss))
shutil.copy(DATA_ROOT_DIR + VERSION + '.h5', '/content/drive/MyDrive/Models/%s-%.4f.h5' % (VERSION, val_loss))
# Out:
# '/content/drive/MyDrive/Models/ResNet34-UNet-v3-0.3013.h5'
