# %% [markdown]
# # Image Segmentation U-Net
#
# + [https://ithelp.ithome.com.tw/articles/10240314](https://ithelp.ithome.com.tw/articles/10240314)
# + [https://www.kaggle.com/tikutiku/hubmap-tilespadded-inference-v2](https://www.kaggle.com/tikutiku/hubmap-tilespadded-inference-v2)
#
# 由 SKNet50-CBAM-Hypercol.ipynb 再做調整，將 CBAM 提前至 Encoding 階段執行

# %% [markdown]
# # Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !tar -xf "/content/drive/MyDrive/Colab Notebooks/annotations.tar.gz" -C /content
# !tar -xf "/content/drive/MyDrive/Colab Notebooks/images.tar.gz" -C /content

# %%
import os

# https://stackoverflow.com/questions/60058588/tesnorflow-2-0-tf-random-set-seed-not-working-since-i-am-getting-different-resul
SEED = 2021
os.environ['PYTHONHASHSEED'] = str(SEED)

# %%
import numpy
import math
import random

VERSION = 'SKNet50-UNet-v2'
DATA_ROOT_DIR = '/content/'
SEED = 2021
IMG_SIZE = (160, 160)
NUM_CLASSES = 4
BATCH_SIZE = 20
EPOCHES = 50

import tensorflow.keras as keras
from keras import layers, models
import tensorflow as tf

def reset_random_seed():
    os.environ['PYTHONHASHSEED'] = str(SEED)
    numpy.random.seed(SEED)
    random.seed(SEED)
    tf.random.set_seed(SEED)
reset_random_seed()

# %%
files = []

for file in os.listdir(DATA_ROOT_DIR + 'images'):
    # file = Abyssinian_1.jpg
    if file.endswith('jpg'):
        fn = file.split('.')[0]
        if os.path.isfile(DATA_ROOT_DIR + 'annotations/trimaps/' + fn + '.png'):
            files.append(fn)
files = sorted(files)

# %%
from IPython.display import display
from tensorflow.keras.preprocessing.image import load_img
from PIL import ImageOps
import PIL

# ImageOps.autocontrast() method maximizes (normalize) image contrast. 
# This function calculates a histogram of the input image, 
# removes cutoff percent of the lightest and darkest pixels from the histogram, 
# and remaps the image so that the darkest pixel becomes black (0), 
# and the lightest becomes white (255).

img = PIL.ImageOps.autocontrast(load_img(DATA_ROOT_DIR + 'annotations/trimaps/' + files[0] + '.png'))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7FDC0C0FDDD0>

# %% [markdown]
# ## Data Generator

# %%
# reference: https://www.tensorflow.org/api_docs/python/tf/keras/utils/Sequence
class OxfordPets(keras.utils.Sequence):
    def __init__(self, files):
        self.files = files
    def __len__(self):
        return math.ceil(len(self.files) / BATCH_SIZE)
    def __getitem__(self, index):
        x, y = [], []
        for i in range(index * BATCH_SIZE, min((index+1) * BATCH_SIZE, len(self.files))):
            # target size in load_img
            # (img_height, img_width)
            x.append(numpy.array(load_img(DATA_ROOT_DIR + 'images/' + self.files[i] + '.jpg', target_size = IMG_SIZE), dtype='float32'))
            y.append(numpy.array(load_img(DATA_ROOT_DIR + 'annotations/trimaps/' + self.files[i] + '.png', target_size = IMG_SIZE, color_mode="grayscale"), dtype='uint8'))

        return numpy.array(x), numpy.array(y)

# %% [markdown]
# ## Build model

# %%
class SKUnit(keras.Model):
    def __init__(self, filters, strides, M=2, G=32, r=16, L=32):
        """ Constructor
        Args:
            M: the number of branchs.
            G: num of convolution groups.
            r: the ratio for compute d, the length of z.
            L: the minimum dim of the vector z in paper, default 32.
        """
        super().__init__()
        self.M = M
        self.filters = filters

        self.convs = []  # 各分支的卷積層
        for i in range(M):
            self.convs.append(models.Sequential([
                layers.Conv2D(filters, 3+2*i, strides,
                              padding='same', groups=G),
                layers.BatchNormalization(),
                layers.Activation('relu'),
            ]))

        self.gap = layers.GlobalAveragePooling2D()
        self.fc = layers.Dense(max(filters//r, L))
        self.fcs = []
        for i in range(M):
          self.fcs.append(layers.Dense(filters))

    def call(self, input):
        # 計算不同分支的 U
        for i in range(self.M):
            feat = self.convs[i](input)
            feat = tf.expand_dims(feat, axis=-1)
            feats_U = feat if i == 0 else tf.concat([feats_U, feat], axis=-1)

        # feats_U (H, W, filters, M)

        # 對 U 做全局平均池化得到 s
        feats_s = self.gap(tf.reduce_sum(feats_U, axis=-1))

        # s 經過全連結層可以得到 z
        feats_Z = self.fc(feats_s)

        for i in range(self.M):
            fcs = self.fcs[i](feats_Z)
            att_vec = fcs if i == 0 else tf.concat([att_vec, fcs], axis=-1)

        att_vec = layers.Reshape((1, 1, self.filters, self.M))(att_vec)
        att_vec = tf.nn.softmax(att_vec, axis=-1)

        # att_vec (1, 1, filters, M)

        mul = tf.multiply(feats_U, att_vec)

        return tf.reduce_sum(mul, axis=-1)


class SKConv(keras.Model):
    def __init__(self, filters, strides, M=2, G=32, r=16, L=32):
        super().__init__()
        self.filters = filters
        self.strides = strides

        #----------------------------- conv1x1_1 -----------------------------
        self.conv1x1_1 = layers.Conv2D(filters, 1, 1)
        self.bn1 = layers.BatchNormalization()

        #------------------------------ middle -------------------------------
        self.skunit = SKUnit(filters, strides, M, G, r, L)
        self.bn2 = layers.BatchNormalization()

        #----------------------------- conv1x1_2 -----------------------------
        self.conv1x1_2 = layers.Conv2D(filters*2, 1, 1)
        self.bn3 = layers.BatchNormalization()

    def build(self, input_shape):
        if input_shape[-1] != self.filters*2:
            self.shortcut = models.Sequential([
                layers.Conv2D(self.filters*2, 1, self.strides),
                layers.BatchNormalization()
            ])
        else:
            self.shortcut = models.Sequential()

    def call(self, input):
        x = input
        x = self.conv1x1_1(x)
        x = self.bn1(x)
        x = tf.nn.relu(x)

        x = self.skunit(x)
        x = self.bn2(x)

        x = self.conv1x1_2(x)
        x = self.bn3(x)
        x = tf.nn.relu(x)

        shortcut = self.shortcut(input)

        return tf.nn.relu(tf.add(x, shortcut))

class Encoder(keras.Model):
    def __init__(self, filters, strides, repeat, M=2, G=32, r=16, L=32):
        super().__init__()
        self.resBlocks = keras.Sequential()
        self.resBlocks.add(SKConv(filters, strides, M, G, r, L))
        for _ in range(1, repeat):
            self.resBlocks.add(
                SKConv(filters, 1, M, G, r, L))

    def call(self, inputs):
        return self.resBlocks(inputs)

    def get_config(self):
        return {}


class ChannelAttention(keras.Model):
    def __init__(self, reduction):
        super().__init__()
        self.globalMaxPool = layers.GlobalMaxPooling2D(keepdims=True)
        self.globalAvgPool = layers.GlobalAveragePooling2D(keepdims=True)
        self.reduction = reduction

    def build(self, input_shape):
        self.fc = keras.Sequential([
            layers.Conv2D(input_shape[-1]//self.reduction, 3, padding='same'),
            layers.ReLU(),
            layers.Conv2D(input_shape[-1], 1, padding='valid')
        ])

    def call(self, inputs):
        x1 = self.globalMaxPool(inputs)
        x2 = self.globalAvgPool(inputs)
        x1 = self.fc(x1)
        x2 = self.fc(x2)
        x = tf.nn.sigmoid(layers.add([x1, x2]))
        return x


class SpatialAttention(keras.Model):
    def __init__(self):
        super().__init__()
        self.conv3x3 = layers.Conv2D(1, 3, padding='same')

    def call(self, inputs):
        # https://github.com/kobiso/CBAM-tensorflow/blob/master/attention_module.py#L95
        x1 = tf.math.reduce_max(inputs, axis=3, keepdims=True)
        x2 = tf.math.reduce_mean(inputs, axis=3, keepdims=True)
        x = tf.concat([x1, x2], 3)
        x = self.conv3x3(x)
        x = tf.nn.sigmoid(x)
        return x


class CBAM(keras.Model):
    def __init__(self, reduction):
        super().__init__()
        self.channelAttention = ChannelAttention(reduction)
        self.spaialAttention = SpatialAttention()

    def call(self, inputs):
        x = inputs * self.channelAttention(inputs)
        x = x * self.spaialAttention(x)
        return x


class Decoder(keras.Model):
    def __init__(self, channels, upsample=True):
        super().__init__()
        self.bn1 = layers.BatchNormalization()
        self.bn2 = layers.BatchNormalization()

        if upsample:
            self.upsample = keras.Sequential([
                layers.UpSampling2D(2, interpolation='nearest')
            ])
        else:
            self.upsample = keras.Sequential()

        self.conv3x3_2 = layers.Conv2D(
            channels, 3, padding='same', use_bias=False)
        self.conv1x1 = layers.Conv2D(channels, 1, use_bias=False)

    def build(self, input_shape):
        self.conv3x3_1 = layers.Conv2D(
            input_shape[-1], 3, padding='same', use_bias=False)

    def call(self, inputs):
        x = self.bn1(inputs)
        x = tf.nn.relu(x)
        x = self.upsample(x)
        x = self.conv3x3_1(x)
        x = self.bn2(x)
        x = tf.nn.relu(x)
        x = self.conv3x3_2(x)

        shortcut = self.conv1x1(self.upsample(inputs))
        x += shortcut
        return x

    def get_config(self):
        return {}


def SKNet50UNetV2(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Encode by SKNet50
    x = layers.Conv2D(64, 7, strides=2, padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = tf.nn.relu(x)
    x0 = layers.MaxPooling2D(3, strides=2, padding='same')(x)

    # SKNet50
    x1 = Encoder(filters=128, strides=1, repeat=3)(CBAM(reduction=16)(x0))
    x2 = Encoder(filters=256, strides=2, repeat=4)(CBAM(reduction=16)(x1))
    x3 = Encoder(filters=512, strides=2, repeat=6)(CBAM(reduction=16)(x2))
    x4 = Encoder(filters=1024, strides=2, repeat=5)(CBAM(reduction=16)(x3))

    # Center Block
    y5 = layers.Conv2D(512, 3, padding='same', use_bias=False)(x4)

    # Decode
    y4 = Decoder(64)(layers.Concatenate(axis=3)([x4, y5]))
    y3 = Decoder(64)(layers.Concatenate(axis=3)([x3, y4]))
    y2 = Decoder(64)(layers.Concatenate(axis=3)([x2, y3]))
    y1 = Decoder(64)(layers.Concatenate(axis=3)([x1, y2]))
    y0 = Decoder(64)(y1)

    # Hypercolumn
    y4 = layers.UpSampling2D(16, interpolation='bilinear')(y4)
    y3 = layers.UpSampling2D(8, interpolation='bilinear')(y3)
    y2 = layers.UpSampling2D(4, interpolation='bilinear')(y2)
    y1 = layers.UpSampling2D(2, interpolation='bilinear')(y1)
    hypercolumn = layers.Concatenate(axis=3)([y0, y1, y2, y3, y4])

    # Final conv
    outputs = keras.Sequential([
        layers.Conv2D(64, 3, padding='same', use_bias=False),
        layers.ELU(),
        layers.Conv2D(num_classes, 1, use_bias=False)
    ])(hypercolumn)

    outputs = tf.nn.softmax(outputs)
    return keras.Model(inputs, outputs)

# %% [markdown]
# ## Start Training!

# %%
keras.backend.clear_session()
reset_random_seed()

m = SKNet50UNetV2(IMG_SIZE+(3,), NUM_CLASSES)
m.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 80, 80, 64)   9408        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 80, 80, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu (TFOpLambda)         (None, 80, 80, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 40, 40, 64)   0           tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# cbam (CBAM)                     (None, 40, 40, 64)   2647        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# encoder (Encoder)               (None, 40, 40, 256)  290784      cbam[0][0]
# __________________________________________________________________________________________________
# cbam_1 (CBAM)                   (None, 40, 40, 256)  41251       encoder[0][0]
# __________________________________________________________________________________________________
# encoder_1 (Encoder)             (None, 20, 20, 512)  1525376     cbam_1[0][0]
# __________________________________________________________________________________________________
# cbam_2 (CBAM)                   (None, 20, 20, 512)  164403      encoder_1[0][0]
# __________________________________________________________________________________________________
# encoder_2 (Encoder)             (None, 10, 10, 1024) 8620224     cbam_2[0][0]
# __________________________________________________________________________________________________
# cbam_3 (CBAM)                   (None, 10, 10, 1024) 656467      encoder_2[0][0]
# __________________________________________________________________________________________________
# encoder_3 (Encoder)             (None, 5, 5, 2048)   28742976    cbam_3[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 5, 5, 512)    9437184     encoder_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 5, 5, 2560)   0           encoder_3[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# decoder (Decoder)               (None, 10, 10, 64)   60641280    concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 10, 10, 1088) 0           encoder_2[0][0]
#                                                                  decoder[0][0]
# __________________________________________________________________________________________________
# decoder_1 (Decoder)             (None, 20, 20, 64)   11358720    concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 20, 20, 576)  0           encoder_1[0][0]
#                                                                  decoder_1[0][0]
# __________________________________________________________________________________________________
# decoder_2 (Decoder)             (None, 40, 40, 64)   3359232     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 40, 40, 320)  0           encoder[0][0]
#                                                                  decoder_2[0][0]
# __________________________________________________________________________________________________
# decoder_3 (Decoder)             (None, 80, 80, 64)   1128960     concatenate_3[0][0]
# __________________________________________________________________________________________________
# decoder_4 (Decoder)             (None, 160, 160, 64) 78336       decoder_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 160, 160, 64) 0           decoder_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 160, 160, 64) 0           decoder_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 160, 160, 64) 0           decoder_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 160, 160, 64) 0           decoder[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 160, 160, 320 0           decoder_4[0][0]
#                                                                  up_sampling2d_8[0][0]
#                                                                  up_sampling2d_7[0][0]
#                                                                  up_sampling2d_6[0][0]
#                                                                  up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# sequential_45 (Sequential)      (None, 160, 160, 4)  184576      concatenate_4[0][0]
# __________________________________________________________________________________________________
# tf.nn.softmax (TFOpLambda)      (None, 160, 160, 4)  0           sequential_45[0][0]
# ==================================================================================================
# Total params: 126,242,080
# Trainable params: 126,100,640
# Non-trainable params: 141,440
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(m, show_shapes=True)

# %%
files = sorted(files)
rng = numpy.random.default_rng(SEED)
rng.shuffle(files)

middle = math.ceil(len(files) * 0.8)
train = OxfordPets(files[:middle])
test = OxfordPets(files[middle:])

# 確定每次訓練時 files 的順序皆相同
print(files[:10])
# Out:
# ['japanese_chin_19', 'english_setter_184', 'Bengal_103', 'Bengal_12', 'american_bulldog_133', 'shiba_inu_12', 'Bombay_69', 'leonberger_189', 'Bombay_171', 'saint_bernard_103']

# %%
keras.backend.clear_session()
reset_random_seed()

callbacks = [
    keras.callbacks.ModelCheckpoint(DATA_ROOT_DIR + VERSION + ".h5", monitor='val_loss', save_best_only=True, save_weights_only=True)
]

m.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=['accuracy'])
history = m.fit(train, validation_data=test, epochs=EPOCHES, callbacks=callbacks)
# Out:
# Epoch 1/50
# 296/296 [==============================] - 404s 1s/step - loss: 2.0681 - accuracy: 0.6729 - val_loss: 0.9430 - val_accuracy: 0.5595
# Epoch 2/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.6341 - accuracy: 0.7401 - val_loss: 0.8878 - val_accuracy: 0.6187
# Epoch 3/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.5734 - accuracy: 0.7685 - val_loss: 0.5615 - val_accuracy: 0.7757
# Epoch 4/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.5256 - accuracy: 0.7904 - val_loss: 0.5437 - val_accuracy: 0.7873
# Epoch 5/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.4843 - accuracy: 0.8090 - val_loss: 0.6619 - val_accuracy: 0.7462
# Epoch 6/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.4554 - accuracy: 0.8213 - val_loss: 0.6059 - val_accuracy: 0.7706
# Epoch 7/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.4288 - accuracy: 0.8322 - val_loss: 0.4871 - val_accuracy: 0.8103
# Epoch 8/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.4057 - accuracy: 0.8419 - val_loss: 0.6491 - val_accuracy: 0.7918
# Epoch 9/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.3760 - accuracy: 0.8534 - val_loss: 0.5897 - val_accuracy: 0.7803
# Epoch 10/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.3633 - accuracy: 0.8584 - val_loss: 0.4787 - val_accuracy: 0.8191
# Epoch 11/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.3376 - accuracy: 0.8685 - val_loss: 0.6614 - val_accuracy: 0.7604
# Epoch 12/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.3134 - accuracy: 0.8774 - val_loss: 0.5569 - val_accuracy: 0.8239
# Epoch 13/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.3023 - accuracy: 0.8816 - val_loss: 0.4997 - val_accuracy: 0.8251
# Epoch 14/50
# 296/296 [==============================] - 378s 1s/step - loss: 0.3026 - accuracy: 0.8823 - val_loss: 0.4859 - val_accuracy: 0.8245
# Epoch 15/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.2840 - accuracy: 0.8892 - val_loss: 0.5141 - val_accuracy: 0.8287
# Epoch 16/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.2755 - accuracy: 0.8923 - val_loss: 0.4557 - val_accuracy: 0.8370
# Epoch 17/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.2666 - accuracy: 0.8961 - val_loss: 0.4274 - val_accuracy: 0.8451
# Epoch 18/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.2536 - accuracy: 0.9007 - val_loss: 0.4618 - val_accuracy: 0.8429
# Epoch 19/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.2430 - accuracy: 0.9045 - val_loss: 0.4804 - val_accuracy: 0.8321
# Epoch 20/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.2355 - accuracy: 0.9075 - val_loss: 0.4803 - val_accuracy: 0.8336
# Epoch 21/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.2261 - accuracy: 0.9109 - val_loss: 0.4042 - val_accuracy: 0.8604
# Epoch 22/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.2180 - accuracy: 0.9138 - val_loss: 0.7482 - val_accuracy: 0.7722
# Epoch 23/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.2343 - accuracy: 0.9080 - val_loss: 0.6800 - val_accuracy: 0.8119
# Epoch 24/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.2172 - accuracy: 0.9141 - val_loss: 0.7635 - val_accuracy: 0.7943
# Epoch 25/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.2064 - accuracy: 0.9182 - val_loss: 0.6534 - val_accuracy: 0.8005
# Epoch 26/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.2094 - accuracy: 0.9169 - val_loss: 0.4266 - val_accuracy: 0.8526
# Epoch 27/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.1725 - accuracy: 0.9305 - val_loss: 0.3856 - val_accuracy: 0.8740
# Epoch 28/50
# 296/296 [==============================] - 386s 1s/step - loss: 0.1946 - accuracy: 0.9223 - val_loss: 0.4994 - val_accuracy: 0.8363
# Epoch 29/50
# 296/296 [==============================] - 385s 1s/step - loss: 0.2172 - accuracy: 0.9146 - val_loss: 0.8819 - val_accuracy: 0.7201
# Epoch 30/50
# 296/296 [==============================] - 365s 1s/step - loss: 0.9781 - accuracy: 0.5808 - val_loss: 0.9249 - val_accuracy: 0.5921
# Epoch 31/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9320 - accuracy: 0.5794 - val_loss: 0.9220 - val_accuracy: 0.5921
# Epoch 32/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9314 - accuracy: 0.5794 - val_loss: 0.9264 - val_accuracy: 0.5921
# Epoch 33/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9319 - accuracy: 0.5794 - val_loss: 0.9212 - val_accuracy: 0.5921
# Epoch 34/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9317 - accuracy: 0.5794 - val_loss: 0.9221 - val_accuracy: 0.5921
# Epoch 35/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9316 - accuracy: 0.5794 - val_loss: 0.9218 - val_accuracy: 0.5921
# Epoch 36/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9315 - accuracy: 0.5794 - val_loss: 0.9231 - val_accuracy: 0.5921
# Epoch 37/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9317 - accuracy: 0.5794 - val_loss: 0.9220 - val_accuracy: 0.5921
# Epoch 38/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9319 - accuracy: 0.5794 - val_loss: 0.9245 - val_accuracy: 0.5921
# Epoch 39/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9319 - accuracy: 0.5794 - val_loss: 0.9218 - val_accuracy: 0.5921
# Epoch 40/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9313 - accuracy: 0.5794 - val_loss: 0.9218 - val_accuracy: 0.5921
# Epoch 41/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9313 - accuracy: 0.5794 - val_loss: 0.9231 - val_accuracy: 0.5921
# Epoch 42/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9317 - accuracy: 0.5794 - val_loss: 0.9240 - val_accuracy: 0.5921
# Epoch 43/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9316 - accuracy: 0.5794 - val_loss: 0.9217 - val_accuracy: 0.5921
# Epoch 44/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9318 - accuracy: 0.5794 - val_loss: 0.9215 - val_accuracy: 0.5921
# Epoch 45/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9321 - accuracy: 0.5794 - val_loss: 0.9218 - val_accuracy: 0.5921
# Epoch 46/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9319 - accuracy: 0.5794 - val_loss: 0.9251 - val_accuracy: 0.5921
# Epoch 47/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9317 - accuracy: 0.5794 - val_loss: 0.9224 - val_accuracy: 0.5921
# Epoch 48/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9317 - accuracy: 0.5794 - val_loss: 0.9214 - val_accuracy: 0.5921
# Epoch 49/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9316 - accuracy: 0.5794 - val_loss: 0.9214 - val_accuracy: 0.5921
# Epoch 50/50
# 296/296 [==============================] - 362s 1s/step - loss: 0.9317 - accuracy: 0.5794 - val_loss: 0.9234 - val_accuracy: 0.5921

# %% [markdown]
# # Evaluate

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 2])
plt.legend(loc='upper right')

print(min(history.history['val_loss']))
# Out:
# 0.3856257200241089

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

print(max(history.history['val_accuracy']))
# Out:
# 0.8739829063415527

# %%
import json
with open(DATA_ROOT_DIR + VERSION + '.json', 'w') as f:
    data = {
        'loss': history.history['loss'],
        'val_loss': history.history['val_loss']
    }
    json.dump(data, f)

# %% [markdown]
# ## Show result

# %%
def mask_to_img(predict):
    mask = numpy.argmax(predict, axis=-1)
    # numpy.expand_dims() expand the shape of an array.
    # Insert a new axis that will appear at the axis position in the expanded
    # array shape.
    mask = numpy.expand_dims(mask, axis = -1)
    return PIL.ImageOps.autocontrast(keras.preprocessing.image.array_to_img(mask))

# %%
demo_data = OxfordPets(files[:20])
demo_res = m.predict(demo_data)

plt.figure(figsize=(8, 10))
for i in range(20):
    plt.subplot(5, 4, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(keras.preprocessing.image.array_to_img(demo_data.__getitem__(0)[0][i]))
    plt.imshow(mask_to_img(demo_res[i]), cmap='jet', alpha=0.3)

plt.show()
plt.close()

# %%
import shutil
val_loss = min(history.history['val_loss'])

shutil.copy(DATA_ROOT_DIR + VERSION + '.json', '/content/drive/MyDrive/Models/%s-%.4f.json' % (VERSION, val_loss))
shutil.copy(DATA_ROOT_DIR + VERSION + '.h5', '/content/drive/MyDrive/Models/%s-%.4f.h5' % (VERSION, val_loss))
# Out:
# '/content/drive/MyDrive/Models/SKNet50-UNet-v2-0.3856.h5'
