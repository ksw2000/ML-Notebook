# %% [markdown]
# # Image Segmentation U-Net v2
#
# + [https://ithelp.ithome.com.tw/articles/10240314](https://ithelp.ithome.com.tw/articles/10240314)
# + [https://www.kaggle.com/tikutiku/hubmap-tilespadded-inference-v2](https://www.kaggle.com/tikutiku/hubmap-tilespadded-inference-v2)
#
# 由 resnet34-cbam-hypercol.ipynb 再做調整，將 CBAM 提前至 Encoding 階段執行

# %% [markdown]
# # Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !tar -xf "/content/drive/MyDrive/Colab Notebooks/annotations.tar.gz" -C /content
# !tar -xf "/content/drive/MyDrive/Colab Notebooks/images.tar.gz" -C /content

# %%
import os
import numpy
import math
import random

VERSION = 'ResNet34-UNet-v2'
DATA_ROOT_DIR = '/content/'
SEED = 2021
IMG_SIZE = (160, 160)
NUM_CLASSES = 4
BATCH_SIZE = 25
EPOCHES = 50

# https://stackoverflow.com/questions/60058588/tesnorflow-2-0-tf-random-set-seed-not-working-since-i-am-getting-different-resul
os.environ['PYTHONHASHSEED'] = str(SEED)
numpy.random.seed(SEED)
random.seed(SEED)

import tensorflow.keras as keras
import keras.layers as layers
import tensorflow as tf

tf.random.set_seed(SEED)

# %%
files = []

for file in os.listdir(DATA_ROOT_DIR + 'images'):
    # file = Abyssinian_1.jpg
    if file.endswith('jpg'):
        fn = file.split('.')[0]
        if os.path.isfile(DATA_ROOT_DIR + 'annotations/trimaps/' + fn + '.png'):
            files.append(fn)
files = sorted(files)

# %%
from IPython.display import display
from tensorflow.keras.preprocessing.image import load_img
from PIL import ImageOps
import PIL

# ImageOps.autocontrast() method maximizes (normalize) image contrast. 
# This function calculates a histogram of the input image, 
# removes cutoff percent of the lightest and darkest pixels from the histogram, 
# and remaps the image so that the darkest pixel becomes black (0), 
# and the lightest becomes white (255).

img = PIL.ImageOps.autocontrast(load_img(DATA_ROOT_DIR + 'annotations/trimaps/' + files[0] + '.png'))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7F6513D5DC90>

# %% [markdown]
# ## Data Generator

# %%
# reference: https://www.tensorflow.org/api_docs/python/tf/keras/utils/Sequence
class OxfordPets(keras.utils.Sequence):
    def __init__(self, files):
        self.files = files
    def __len__(self):
        return math.ceil(len(self.files) / BATCH_SIZE)
    def __getitem__(self, index):
        x, y = [], []
        for i in range(index * BATCH_SIZE, min((index+1) * BATCH_SIZE, len(self.files))):
            # target size in load_img
            # (img_height, img_width)
            x.append(numpy.array(load_img(DATA_ROOT_DIR + 'images/' + self.files[i] + '.jpg', target_size = IMG_SIZE), dtype='float32'))
            y.append(numpy.array(load_img(DATA_ROOT_DIR + 'annotations/trimaps/' + self.files[i] + '.png', target_size = IMG_SIZE, color_mode="grayscale"), dtype='uint8'))

        return numpy.array(x), numpy.array(y)

# %% [markdown]
# ## U-Net

# %%
class ResBlock(keras.Model):
    def __init__(self, channels, strides=1):
        super().__init__()

        self.conv1 = layers.Conv2D(channels, 3, strides=strides, padding='same', use_bias=False)
        self.bn1 = layers.BatchNormalization()
        self.conv2 = layers.Conv2D(channels, 3, strides=1, padding='same', use_bias=False)
        self.bn2 = layers.BatchNormalization()

        if strides != 1:
            self.shortcut = keras.Sequential([
                layers.Conv2D(channels, 1, strides, padding='same', use_bias=False)
            ])
        else:
            self.shortcut = keras.Sequential()
        
    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.bn1(x)
        x = tf.nn.relu(x)

        x = self.conv2(x)
        x = self.bn2(x)

        shortcut = self.shortcut(inputs)
        return tf.nn.relu(tf.add(x, shortcut))
    
    def get_config(self):
        return {}

class Encoder(keras.Model):
    def __init__(self, channels, repeat, strides):
        super().__init__()
        self.resBlocks = keras.Sequential()
        self.resBlocks.add(ResBlock(channels, strides))
        for _ in range(1, repeat):
            self.resBlocks.add(ResBlock(channels, strides=1))

    def call(self, inputs):
        return self.resBlocks(inputs)
    
    def get_config(self):
        return {}

# %%
class ChannelAttention(keras.Model):
    def __init__(self, reduction):
        super().__init__()
        self.globalMaxPool = layers.GlobalMaxPooling2D(keepdims=True)
        self.globalAvgPool = layers.GlobalAveragePooling2D(keepdims=True)
        self.reduction = reduction
    
    def build(self, input_shape):
        self.fc = keras.Sequential([
            layers.Conv2D(input_shape[-1]//self.reduction, 3, padding='same', use_bias=False),
            layers.ReLU(),
            layers.Conv2D(input_shape[-1], 1, use_bias=False)
        ])
    
    def call(self, inputs):
        x1 = self.globalMaxPool(inputs)
        x2 = self.globalAvgPool(inputs)
        x1 = self.fc(x1)
        x2 = self.fc(x2)
        x = tf.nn.sigmoid(layers.add([x1, x2]))
        return x

    def get_config(self):
        return {
            'reduction': self.reduction
        }

class SpatialAttention(keras.Model):
    def __init__(self):
        super().__init__()
        self.conv3x3 = layers.Conv2D(1, 3, padding='same', use_bias=False)
    
    def call(self, inputs):
        # https://github.com/kobiso/CBAM-tensorflow/blob/master/attention_module.py#L95
        x1 = tf.math.reduce_max(inputs, axis=-1, keepdims=True)
        x2 = tf.math.reduce_mean(inputs, axis=-1, keepdims=True)
        x = tf.concat([x1, x2], axis=-1)
        x = self.conv3x3(x)
        x = tf.nn.sigmoid(x)
        return x
    
    def get_config(self):
        return {}

class CBAM(keras.Model):
    def __init__(self, reduction):
        super().__init__()
        self.channelAttention = ChannelAttention(reduction)
        self.spatialAttention = SpatialAttention()
    
    def call(self, inputs):
        x = inputs * self.channelAttention(inputs)
        x = x * self.spatialAttention(x)
        return x
    
    def get_config(self):
        return {}

# %%
class DecodeBlock(keras.Model):
    def __init__(self, channels, upsample=True):
        super().__init__()
        self.bn1 = layers.BatchNormalization()
        self.bn2 = layers.BatchNormalization()

        if upsample:
            self.upsample = keras.Sequential([
              layers.UpSampling2D(2, interpolation='nearest')     
            ])
        else:
            self.upsample = keras.Sequential()
        
        self.conv3x3_2 = layers.Conv2D(channels, 3, padding='same', use_bias=False)
        self.conv1x1 = layers.Conv2D(channels, 1, use_bias=False)
        
    def build(self, input_shape):
        self.conv3x3_1 = layers.Conv2D(input_shape[-1], 3, padding='same', use_bias=False)

    def call(self, inputs):
        x = self.bn1(inputs)
        x = tf.nn.relu(x)
        x = self.upsample(x)
        x = self.conv3x3_1(x)
        x = self.bn2(x)
        x = tf.nn.relu(x)
        x = self.conv3x3_2(x)

        shortcut = self.conv1x1(self.upsample(inputs))
        x += shortcut
        return x

    def get_config(self):
        return {}

# %%
def UNet(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Encode by ResNet34
    x = layers.Conv2D(64, 7, strides=2, padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = tf.nn.relu(x)
    x0 = layers.MaxPooling2D(3, strides=2, padding='same')(x)
    
    # ResNet34 is referenced by https://blog.csdn.net/Forrest97/article/details/106136435
    
    # ResNet34 - layer1
    x1 = Encoder(64, 3, strides=1)(CBAM(reduction=16)(x0))
    
    # ResNet34 - layer2
    x2 = Encoder(128, 4, strides=2)(CBAM(reduction=16)(x1))

    # ResNet34 - layer3
    x3 = Encoder(256, 6, strides=2)(CBAM(reduction=16)(x2))

    # ResNet34 - layer4
    x4 = Encoder(512, 3, strides=2)(CBAM(reduction=16)(x3))

    # centerblock
    y5 = layers.Conv2D(512, 3, padding='same', use_bias=False)(x4)

    # Decode

    y4 = DecodeBlock(64)(layers.Concatenate(axis=3)([x4, y5]))

    y3 = DecodeBlock(64)(layers.Concatenate(axis=3)([x3, y4]))

    y2 = DecodeBlock(64)(layers.Concatenate(axis=3)([x2, y3]))

    y1 = DecodeBlock(64)(layers.Concatenate(axis=3)([x1, y2]))

    y0 = DecodeBlock(64)(y1)

    # hypercolumn
    y4 = layers.UpSampling2D(16, interpolation='bilinear')(y4)
    y3 = layers.UpSampling2D(8, interpolation='bilinear')(y3)
    y2 = layers.UpSampling2D(4, interpolation='bilinear')(y2)
    y1 = layers.UpSampling2D(2, interpolation='bilinear')(y1)
    hypercolumn = layers.Concatenate(axis=3)([y0, y1, y2, y3, y4])

    # final conv
    outputs = keras.Sequential([
        layers.Conv2D(64, 3, padding='same', use_bias=False),
        layers.ELU(),
        layers.Conv2D(num_classes, 1, use_bias=False)
    ])(hypercolumn)

    outputs = tf.nn.softmax(outputs)

    return keras.Model(inputs, outputs)

keras.backend.clear_session()

# %% [markdown]
# ## Start Training!

# %%
m = UNet(IMG_SIZE+(3,), NUM_CLASSES)
m.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 80, 80, 64)   9408        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 80, 80, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu (TFOpLambda)         (None, 80, 80, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 40, 40, 64)   0           tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# cbam (CBAM)                     (None, 40, 40, 64)   2578        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# encoder (Encoder)               (None, 40, 40, 64)   222720      cbam[0][0]
# __________________________________________________________________________________________________
# cbam_1 (CBAM)                   (None, 40, 40, 64)   2578        encoder[0][0]
# __________________________________________________________________________________________________
# encoder_1 (Encoder)             (None, 20, 20, 128)  1118208     cbam_1[0][0]
# __________________________________________________________________________________________________
# cbam_2 (CBAM)                   (None, 20, 20, 128)  10258       encoder_1[0][0]
# __________________________________________________________________________________________________
# encoder_2 (Encoder)             (None, 10, 10, 256)  6828032     cbam_2[0][0]
# __________________________________________________________________________________________________
# cbam_3 (CBAM)                   (None, 10, 10, 256)  40978       encoder_2[0][0]
# __________________________________________________________________________________________________
# encoder_3 (Encoder)             (None, 5, 5, 512)    13119488    cbam_3[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 5, 5, 512)    2359296     encoder_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 5, 5, 1024)   0           encoder_3[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 10, 10, 64)   10100736    concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 10, 10, 320)  0           encoder_2[0][0]
#                                                                  decode_block[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 20, 20, 64)   1128960     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 20, 20, 192)  0           encoder_1[0][0]
#                                                                  decode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 40, 40, 64)   456192      concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 40, 40, 128)  0           encoder[0][0]
#                                                                  decode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 80, 80, 64)   230400      concatenate_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 160, 160, 64) 78336       decode_block_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 160, 160, 64) 0           decode_block_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 160, 160, 64) 0           decode_block_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 160, 160, 64) 0           decode_block_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 160, 160, 64) 0           decode_block[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 160, 160, 320 0           decode_block_4[0][0]
#                                                                  up_sampling2d_8[0][0]
#                                                                  up_sampling2d_7[0][0]
#                                                                  up_sampling2d_6[0][0]
#                                                                  up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# sequential_25 (Sequential)      (None, 160, 160, 4)  184576      concatenate_4[0][0]
# __________________________________________________________________________________________________
# tf.nn.softmax (TFOpLambda)      (None, 160, 160, 4)  0           sequential_25[0][0]
# ==================================================================================================
# Total params: 35,893,000
# Trainable params: 35,870,856
# Non-trainable params: 22,144
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(m, show_shapes=True)

# %%
keras.backend.clear_session()

numpy.random.shuffle(files)
middle = math.ceil(len(files) * 0.8)
train = OxfordPets(files[:middle])
test = OxfordPets(files[middle:])

callbacks = [
    keras.callbacks.ModelCheckpoint(DATA_ROOT_DIR + VERSION + ".h5", monitor='val_loss', save_best_only=True, save_weights_only=True)
]

m.compile(optimizer="rmsprop", loss="sparse_categorical_crossentropy", metrics=['accuracy'])
history = m.fit(train, validation_data=test, epochs=EPOCHES, callbacks=callbacks)
# Out:
# Epoch 1/50
# 237/237 [==============================] - 82s 315ms/step - loss: 4.4931 - accuracy: 0.6094 - val_loss: 338.0312 - val_accuracy: 0.5770
# Epoch 2/50
# 237/237 [==============================] - 74s 310ms/step - loss: 0.7103 - accuracy: 0.7122 - val_loss: 0.8932 - val_accuracy: 0.6483
# Epoch 3/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.5730 - accuracy: 0.7704 - val_loss: 0.5986 - val_accuracy: 0.7619
# Epoch 4/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.4847 - accuracy: 0.8116 - val_loss: 0.6901 - val_accuracy: 0.7332
# Epoch 5/50
# 237/237 [==============================] - 74s 310ms/step - loss: 0.4247 - accuracy: 0.8358 - val_loss: 0.5372 - val_accuracy: 0.8149
# Epoch 6/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.3861 - accuracy: 0.8511 - val_loss: 0.5287 - val_accuracy: 0.8107
# Epoch 7/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.3585 - accuracy: 0.8614 - val_loss: 0.4034 - val_accuracy: 0.8418
# Epoch 8/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.3358 - accuracy: 0.8705 - val_loss: 0.3996 - val_accuracy: 0.8480
# Epoch 9/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.3165 - accuracy: 0.8779 - val_loss: 0.4227 - val_accuracy: 0.8395
# Epoch 10/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.3005 - accuracy: 0.8843 - val_loss: 0.3136 - val_accuracy: 0.8806
# Epoch 11/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.2821 - accuracy: 0.8907 - val_loss: 0.2745 - val_accuracy: 0.8931
# Epoch 12/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.2690 - accuracy: 0.8957 - val_loss: 0.4809 - val_accuracy: 0.8471
# Epoch 13/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.2572 - accuracy: 0.9000 - val_loss: 0.3016 - val_accuracy: 0.8924
# Epoch 14/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.2441 - accuracy: 0.9049 - val_loss: 0.2550 - val_accuracy: 0.9011
# Epoch 15/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.2351 - accuracy: 0.9081 - val_loss: 0.3802 - val_accuracy: 0.8649
# Epoch 16/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.2231 - accuracy: 0.9127 - val_loss: 0.2718 - val_accuracy: 0.8981
# Epoch 17/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.2165 - accuracy: 0.9150 - val_loss: 0.2474 - val_accuracy: 0.9060
# Epoch 18/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.2079 - accuracy: 0.9176 - val_loss: 0.2503 - val_accuracy: 0.9055
# Epoch 19/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.2006 - accuracy: 0.9205 - val_loss: 0.2287 - val_accuracy: 0.9113
# Epoch 20/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1932 - accuracy: 0.9227 - val_loss: 0.2610 - val_accuracy: 0.9094
# Epoch 21/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1838 - accuracy: 0.9263 - val_loss: 0.2656 - val_accuracy: 0.9059
# Epoch 22/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1779 - accuracy: 0.9282 - val_loss: 0.2645 - val_accuracy: 0.9085
# Epoch 23/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1724 - accuracy: 0.9303 - val_loss: 0.2354 - val_accuracy: 0.9127
# Epoch 24/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1667 - accuracy: 0.9321 - val_loss: 0.2599 - val_accuracy: 0.9126
# Epoch 25/50
# 237/237 [==============================] - 74s 312ms/step - loss: 0.1615 - accuracy: 0.9341 - val_loss: 0.2065 - val_accuracy: 0.9246
# Epoch 26/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1567 - accuracy: 0.9358 - val_loss: 0.2173 - val_accuracy: 0.9186
# Epoch 27/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1504 - accuracy: 0.9380 - val_loss: 0.2796 - val_accuracy: 0.9028
# Epoch 28/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1464 - accuracy: 0.9394 - val_loss: 0.2261 - val_accuracy: 0.9210
# Epoch 29/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1421 - accuracy: 0.9410 - val_loss: 0.2759 - val_accuracy: 0.9067
# Epoch 30/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1378 - accuracy: 0.9425 - val_loss: 0.1871 - val_accuracy: 0.9324
# Epoch 31/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1340 - accuracy: 0.9438 - val_loss: 0.2585 - val_accuracy: 0.9320
# Epoch 32/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1297 - accuracy: 0.9455 - val_loss: 0.1860 - val_accuracy: 0.9348
# Epoch 33/50
# 237/237 [==============================] - 74s 312ms/step - loss: 0.1257 - accuracy: 0.9468 - val_loss: 0.2603 - val_accuracy: 0.9154
# Epoch 34/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1217 - accuracy: 0.9485 - val_loss: 0.2223 - val_accuracy: 0.9231
# Epoch 35/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1178 - accuracy: 0.9499 - val_loss: 0.1959 - val_accuracy: 0.9308
# Epoch 36/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1148 - accuracy: 0.9511 - val_loss: 0.1727 - val_accuracy: 0.9376
# Epoch 37/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.1122 - accuracy: 0.9519 - val_loss: 0.1865 - val_accuracy: 0.9377
# Epoch 38/50
# 237/237 [==============================] - 74s 312ms/step - loss: 0.1079 - accuracy: 0.9536 - val_loss: 0.1973 - val_accuracy: 0.9342
# Epoch 39/50
# 237/237 [==============================] - 74s 312ms/step - loss: 0.1062 - accuracy: 0.9546 - val_loss: 0.1777 - val_accuracy: 0.9428
# Epoch 40/50
# 237/237 [==============================] - 74s 312ms/step - loss: 0.1030 - accuracy: 0.9561 - val_loss: 0.1682 - val_accuracy: 0.9445
# Epoch 41/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.0986 - accuracy: 0.9576 - val_loss: 0.1758 - val_accuracy: 0.9433
# Epoch 42/50
# 237/237 [==============================] - 74s 312ms/step - loss: 0.0964 - accuracy: 0.9587 - val_loss: 0.1742 - val_accuracy: 0.9433
# Epoch 43/50
# 237/237 [==============================] - 74s 312ms/step - loss: 0.0935 - accuracy: 0.9598 - val_loss: 0.1796 - val_accuracy: 0.9432
# Epoch 44/50
# 237/237 [==============================] - 74s 312ms/step - loss: 0.0912 - accuracy: 0.9609 - val_loss: 0.1700 - val_accuracy: 0.9474
# Epoch 45/50
# 237/237 [==============================] - 74s 312ms/step - loss: 0.0891 - accuracy: 0.9618 - val_loss: 0.1684 - val_accuracy: 0.9478
# Epoch 46/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.0863 - accuracy: 0.9631 - val_loss: 0.1813 - val_accuracy: 0.9462
# Epoch 47/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.0843 - accuracy: 0.9639 - val_loss: 0.1739 - val_accuracy: 0.9452
# Epoch 48/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.0823 - accuracy: 0.9647 - val_loss: 0.1879 - val_accuracy: 0.9459
# Epoch 49/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.0796 - accuracy: 0.9659 - val_loss: 0.2406 - val_accuracy: 0.9247
# Epoch 50/50
# 237/237 [==============================] - 74s 311ms/step - loss: 0.0773 - accuracy: 0.9667 - val_loss: 0.2002 - val_accuracy: 0.9475

# %% [markdown]
# # Evaluate

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 2])
plt.legend(loc='upper right')

print(min(history.history['val_loss']))
# Out:
# 0.16815106570720673

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

print(max(history.history['val_accuracy']))
# Out:
# 0.9478080868721008

# %%
import json
with open(DATA_ROOT_DIR + VERSION + '.json', 'w') as f:
    data = {
        'loss': history.history['loss'],
        'val_loss': history.history['val_loss']
    }
    json.dump(data, f)

# %% [markdown]
# ## Show result

# %%
def mask_to_img(predict):
    mask = numpy.argmax(predict, axis=-1)
    # numpy.expand_dims() expand the shape of an array.
    # Insert a new axis that will appear at the axis position in the expanded
    # array shape.
    mask = numpy.expand_dims(mask, axis = -1)
    return PIL.ImageOps.autocontrast(keras.preprocessing.image.array_to_img(mask))

# %%
demo_data = OxfordPets(files[:20])
demo_res = m.predict(demo_data)

plt.figure(figsize=(8, 10))
for i in range(20):
    plt.subplot(5, 4, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(keras.preprocessing.image.array_to_img(demo_data.__getitem__(0)[0][i]))
    plt.imshow(mask_to_img(demo_res[i]), cmap='jet', alpha=0.3)

plt.show()
plt.close()

# %%
import shutil
val_loss = min(history.history['val_loss'])

shutil.copy(DATA_ROOT_DIR + VERSION + '.json', '/content/drive/MyDrive/Models/%s-%.4f.json' % (VERSION, val_loss))
shutil.copy(DATA_ROOT_DIR + VERSION + '.h5', '/content/drive/MyDrive/Models/%s-%.4f.h5' % (VERSION, val_loss))
# Out:
# '/content/drive/MyDrive/Models/ResNet34-UNet-v2-0.1682.h5'
